# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Dataset .csv')

# %%
df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ### Task_1: Restaurant Ratings
#
# ### Analyze the distribution of aggregate ratings and determine the most common rating range.

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
aggregate_rating= df['Aggregate rating'].value_counts()
print(aggregate_rating)
# Out:
# Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64

# %%
comman_rating= aggregate_rating.idxmax()
print('The most Comman rating range is:',comman_rating)
# Out:
# The most Comman rating range is: 0.0

# %%
plt.hist(df['Aggregate rating'],bins =30 , color = 'red',edgecolor = 'blue')
plt.xlabel('Aggregate rating')
plt.ylabel('Counts')
plt.title('Distribution Of Aggregate Ratings')
plt.show()

# %% [markdown]
# ### Calculate the average number of votes received by restaurants.

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
avg_votes = round(df['Votes'].mean(),2)
print('The Average Number Of Votes Received By Restaurants:',avg_votes)
# Out:
# The Average Number Of Votes Received By Restaurants: 156.91

# %% [markdown]
# ### Task_2: Cuisine Combination
#
# ### Identify the most common combinations of cuisines in the dataset.

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
common_combo = df.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending= False)
top_20 = common_combo.head(20)

# %%
print('Top 20 Most Combination Of Cuisines are:',top_20)
# Out:
# Top 20 Most Combination Of Cuisines are:                            Cuisines  Aggregate rating
# 0                     Italian, Deli              4.90
# 1                 Hawaiian, Seafood              4.90
# 2           American, Sandwich, Tea              4.90
# 3               Continental, Indian              4.90
# 4           European, Asian, Indian              4.90
# 5            European, Contemporary              4.90
# 6                  European, German              4.90
# 7          BBQ, Breakfast, Southern              4.90
# 8          American, Coffee and Tea              4.90
# 9                 Sunda, Indonesian              4.90
# 10          American, Burger, Grill              4.90
# 11                Mughlai, Lucknowi              4.90
# 12  Mexican, American, Healthy Food              4.90
# 13     American, Caribbean, Seafood              4.90
# 14          Burger, Bar Food, Steak              4.90
# 15     Italian, Bakery, Continental              4.90
# ...

# %%
plt.figure(figsize=(7, 6))
plt.barh(top_20['Cuisines'], top_20['Aggregate rating'], color='red')
plt.xlabel('Average Aggregate Rating')
plt.ylabel('Cuisines')
plt.title('Top 20 Cuisine With Common Combinations')
plt.gca().invert_yaxis() 
plt.show()

# %% [markdown]
# ### Determine if certain cuisine combinations tend to have higher ratings..

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
max_rating = common_combo.iloc[0]
print('The Max rating is:',max_rating)
# Out:
# The Max rating is: 4.9

# %%
max_rated_restaurant = df.loc[df['Aggregate rating'] == max_rating]
print('Restaurant Having The Higher Rating:',max_rated_restaurant['Restaurant Name'])
# Out:
# Restaurant Having The Higher Rating: 3                                           Ooma
# 8       Spiral - Sofitel Philippine Plaza Manila
# 10                              Silantro Fil-Mex
# 39                                    Coco Bambu
# 48                            Braseiro da G��vea
#                           ...
# 9484              Restaurant Mosaic @ The Orient
# 9514                            Ministry of Crab
# 9524                                Gaga Manjero
# 9538                                   Starbucks
# 9540                            Draft Gastro Pub
# Name: Restaurant Name, Length: 61, dtype: object

# %% [markdown]
# ### Task_3: Geographic Analysis
# ### Plot the locations of restaurants on a map using longitude and latitude coordinates.

# %%
pip install geopandas
geodatasets
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/323.6 kB ? eta -:--:--
#    --------------- ------------------------ 122.9/323.6 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  317.4/323.6 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 323.6/323.6 kB 2.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    - -------------------------------------- 0.6/16.2 MB 17.5 MB/s eta 0:00:01
#    -- ------------------------------------- 0.8/16.2 MB 8.5 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/16.2 MB 7.3 MB/s eta 0:00:03
#    -- ------------------------------------- 0.9/16.2 MB 5.4 MB/s eta 0:00:03
#    -- ------------------------------------- 0.9/16.2 MB 5.4 MB/s eta 0:00:03
#    -- ------------------------------------- 0.9/16.2 MB 5.4 MB/s eta 0:00:03
#    -- ------------------------------------- 0.9/16.2 MB 5.4 MB/s eta 0:00:03
# ...

# %%
pip install geodatasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# ...
#
# ...

# %%
### Plot the locations of restaurants on a map using longitude and latitude coordinates.

# %%
import geopandas 
from geodatasets import get_path
import folium 
from folium.plugins import HeatMap

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
print(df[['Longitude', 'Latitude']])
# Out:
#        Longitude   Latitude
# 0     121.027535  14.565443
# 1     121.014101  14.553708
# 2     121.056831  14.581404
# 3     121.056475  14.585318
# 4     121.057508  14.584450
# ...          ...        ...
# 9546   28.977392  41.022793
# 9547   29.041297  41.009847
# 9548   29.034640  41.055817
# 9549   29.036019  41.057979
# 9550   29.026016  40.984776
#
# [9551 rows x 2 columns]

# %%
gdf = geopandas.GeoDataFrame(
    df,geometry= geopandas.points_from_xy(df.Longitude,df.Latitude),crs='EPSG:4326'
)

# %%
print(gdf.head())
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
world = geopandas.read_file(get_path('naturalearth. land'))
ax = world.plot(color='green', edgecolor='black')
gdf.plot(ax=ax, marker='o', color='blue',markersize=8)
# Out:
# <Axes: >

# %% [markdown]
# ### Identify any patterns or clusters of restaurants in specific areas.

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
world_map = folium.Map(location=[df['Latitude'].mean(),df['Longitude'].mean()],zoom_start =1, height = '100%', widht='100%')

# %%
heat_marker= [[row['Latitude'],row['Longitude']] for i , row in df.iterrows()]
HeatMap(heat_marker, radius = 10).add_to(world_map)

# %%
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### Task_4: Restaurant Chains
# ### Identify if there are any restaurant chains present in the dataset

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
restaurant_chain = df.groupby('Restaurant Name').size().reset_index(name= 'Outlet_count')
new = restaurant_chain[restaurant_chain['Outlet_count']>1]
restaurant_chain = new.sort_values(by = 'Outlet_count',ascending = False)

# %%
print(restaurant_chain[['Restaurant Name','Outlet_count']].head(15))
# Out:
#        Restaurant Name  Outlet_count
# 1098   Cafe Coffee Day            83
# 2098    Domino's Pizza            79
# 6106            Subway            63
# 2716  Green Chick Chop            51
# 4077        McDonald's            48
# 3478         Keventers            34
# 4961         Pizza Hut            30
# 2619             Giani            29
# 680     Baskin Robbins            28
# 663    Barbeque Nation            26
# 670            Barista            22
# 2145    Dunkin' Donuts            22
# 2620           Giani's            22
# 4924     Pind Balluchi            20
# 1758      Costa Coffee            20

# %%
plt.figure(figsize=(25, 8))
plt.bar(restaurant_chain['Restaurant Name'][:15],restaurant_chain['Outlet_count'][:15],color='red')
plt.xlabel('Restaurant Name')
plt.title('Top 15 Restaurant Chains By Number Of Outlets')
plt.ylabel('Number of outlets')
plt.show()

# %% [markdown]
# ### Analyze the ratings and popularity of different restaurant chains.

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
rating = df.groupby('Restaurant Name')['Aggregate rating'].mean().reset_index(name='Average rating').sort_values(by='Average rating',ascending= False)

# %%
top_10_rating = rating.nlargest(10,'Average rating')
print("The Top 10 Restaurant Name With Average Rating:")
print(top_10_rating)
# Out:
# The Top 10 Restaurant Name With Average Rating:
#                      Restaurant Name  Average rating
# 5322  Restaurant Mosaic @ The Orient             4.9
# 4177                Ministry of Crab             4.9
# 4135                           Miann             4.9
# 5757         Shorts Burger and Shine             4.9
# 4165                           Milse             4.9
# 7339                 Yellow Dog Eats             4.9
# 2133                   Duck & Waffle             4.9
# 2559                    Gaga Manjero             4.9
# 4182                 Mirchi And Mime             4.9
# 4078   McGuire's Irish Pub & Brewery             4.9

# %%
votes = df.groupby('Restaurant Name')['Votes'].sum().reset_index(name = 'Total votes').sort_values(by= 'Total votes',ascending = False)

# %%
top_10_votes = votes.nlargest(10,'Total votes')
print("The Top 10 Restaurant Name With Total Votes")
print(top_10_votes)
# Out:
# The Top 10 Restaurant Name With Total Votes
#                 Restaurant Name  Total votes
# 663             Barbeque Nation        28142
# 101   AB's - Absolute Barbecues        13400
# 6943                       Toit        10934
# 785                   Big Chill        10853
# 2297                 Farzi Cafe        10098
# 6988                   Truffles         9682
# 1510                    Chili's         8156
# 2879           Hauz Khas Social         7931
# 3261               Joey's Pizza         7807
# 4902                  Peter Cat         7574

# %%
plt.figure(figsize=(25, 4))
plt.bar(rating['Restaurant Name'][:10],rating['Average rating'][:10],color='red')
plt.xlabel('Restaurant Chain')
plt.title('Top 10 Restaurant Chains By Average Rating')
plt.ylabel('Average Rating')
plt.show()

# %%
plt.figure(figsize=(21, 5))
plt.bar(votes['Restaurant Name'][:10],votes['Total votes'][:10],color='red')
plt.xlabel('Restaurant Chain')
plt.title('Top 10 Restaurant Chains By Total Votes')
plt.ylabel('Total Votes')
plt.show()
